# %% [markdown]
# ## Pandas for Data Science ##

# %%
import pandas as pd
print(pd)
# Out:
# <module 'pandas' from '/home/martin/.local/lib/python3.6/site-packages/pandas/__init__.py'>

# %%
df = pd.read_csv('/home/martin/datasets/flights.csv')
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T05:00:00Z
# 1      1416     5      29  2013-01-01T05:00:00Z
# 2      1089     5      40  2013-01-01T05:00:00Z
# 3      1576     5      45  2013-01-01T05:00:00Z
# 4       762     6       0  2013-01-01T06:00:00Z

# %%
df.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# min       -43.000000       1.000000        1.000000     -86.000000
# 25%        -5.000000    1104.000000     1124.000000     -17.000000
# 50%        -2.000000    1535.000000     1556.000000      -5.000000
# 75%        11.000000    1940.000000     1945.000000      14.000000
# max      1301.000000    2400.000000     2359.000000    1272.000000
#
#               flight       air_time       distance           hour  \
# count  336776.000000  327346.000000  336776.000000  336776.000000
# mean     1971.923620     150.686460    1039.912604      13.180247
# std      1632.471938      93.688305     733.233033       4.661316
# min         1.000000      20.000000      17.000000       1.000000
# 25%       553.000000      82.000000     502.000000       9.000000
# 50%      1496.000000     129.000000     872.000000      13.000000
# 75%      3465.000000     192.000000    1389.000000      17.000000
# max      8500.000000     695.000000    4983.000000      23.000000
#
#               minute
# count  336776.000000
# mean       26.230100
# std        19.300846
# min         0.000000
# 25%         8.000000
# 50%        29.000000
# 75%        44.000000
# max        59.000000

# %%
df.isnull()
# Out:
#          year  month    day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       False  False  False     False           False      False     False
# 1       False  False  False     False           False      False     False
# 2       False  False  False     False           False      False     False
# 3       False  False  False     False           False      False     False
# 4       False  False  False     False           False      False     False
# ...       ...    ...    ...       ...             ...        ...       ...
# 336771  False  False  False      True           False       True      True
# 336772  False  False  False      True           False       True      True
# 336773  False  False  False      True           False       True      True
# 336774  False  False  False      True           False       True      True
# 336775  False  False  False      True           False       True      True
#
#         sched_arr_time  arr_delay  carrier  flight  tailnum  origin   dest  \
# 0                False      False    False   False    False   False  False
# 1                False      False    False   False    False   False  False
# 2                False      False    False   False    False   False  False
# 3                False      False    False   False    False   False  False
# 4                False      False    False   False    False   False  False
# ...                ...        ...      ...     ...      ...     ...    ...
# 336771           False       True    False   False     True   False  False
# 336772           False       True    False   False     True   False  False
# 336773           False       True    False   False    False   False  False
# 336774           False       True    False   False    False   False  False
# 336775           False       True    False   False    False   False  False
#
#         air_time  distance   hour  minute  time_hour
# 0          False     False  False   False      False
# 1          False     False  False   False      False
# 2          False     False  False   False      False
# 3          False     False  False   False      False
# 4          False     False  False   False      False
# ...          ...       ...    ...     ...        ...
# 336771      True     False  False   False      False
# 336772      True     False  False   False      False
# 336773      True     False  False   False      False
# 336774      True     False  False   False      False
# 336775      True     False  False   False      False
#
# [336776 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %%
df = df.drop(['year', 'month', 'day', 'dep_time', 'arr_time', 'flight', 'tailnum', 'air_time',
              'distance', 'hour', 'minute', 'time_hour'], axis=1)
df.head()
# Out:
#    sched_dep_time  dep_delay  sched_arr_time  arr_delay carrier origin dest
# 0             515        2.0             819       11.0      UA    EWR  IAH
# 1             529        4.0             830       20.0      UA    LGA  IAH
# 2             540        2.0             850       33.0      AA    JFK  MIA
# 3             545       -1.0            1022      -18.0      B6    JFK  BQN
# 4             600       -6.0             837      -25.0      DL    LGA  ATL

# %%
pd.value_counts(df['carrier'])
# Out:
# UA    58665
# B6    54635
# EV    54173
# DL    48110
# AA    32729
# MQ    26397
# US    20536
# 9E    18460
# WN    12275
# VX     5162
# FL     3260
# AS      714
# F9      685
# YV      601
# HA      342
# OO       32
# Name: carrier, dtype: int64

# %%
pd.value_counts(df['carrier']).plot.bar()

# %%
df.groupby('carrier').mean()
# Out:
#          sched_dep_time  dep_delay  sched_arr_time  arr_delay
# carrier
# 9E          1471.908830  16.725769     1671.208559   7.379669
# AA          1289.909438   8.586016     1545.118213   0.364291
# AS          1284.502801   5.804775     1595.298319  -9.930889
# B6          1397.168830  13.022522     1469.401666   9.457973
# DL          1346.385284   9.264505     1595.856807   1.644341
# EV          1353.544699  19.955390     1531.607240  15.796431
# F9          1407.802920  20.215543     1645.581022  21.920705
# FL          1371.741411  18.726075     1585.023926  20.115906
# HA           974.385965   4.900585     1491.549708  -6.915205
# MQ          1386.772967  10.552041     1564.162481  10.774733
# OO          1731.281250  12.586207     1889.906250  11.931034
# UA          1312.668849  12.106073     1544.186056   3.558011
# US          1246.062865   3.782418     1411.725847   2.129595
# VX          1264.692755  12.869421     1596.298721   1.764464
# WN          1260.223218  17.711744     1450.437067   9.649120
# YV          1574.542429  18.996330     1743.422629  15.556985

# %%
df.groupby('carrier').mean()['dep_delay']
# Out:
# carrier
# 9E    16.725769
# AA     8.586016
# AS     5.804775
# B6    13.022522
# DL     9.264505
# EV    19.955390
# F9    20.215543
# FL    18.726075
# HA     4.900585
# MQ    10.552041
# OO    12.586207
# UA    12.106073
# US     3.782418
# VX    12.869421
# WN    17.711744
# YV    18.996330
# Name: dep_delay, dtype: float64

# %%
# This will cause an error
df.groupby('carrier').mean()['dep_delay', 'arr_delay']

# %%
df.groupby('carrier').mean()[['dep_delay', 'arr_delay']]
# Out:
#          dep_delay  arr_delay
# carrier
# 9E       16.725769   7.379669
# AA        8.586016   0.364291
# AS        5.804775  -9.930889
# B6       13.022522   9.457973
# DL        9.264505   1.644341
# EV       19.955390  15.796431
# F9       20.215543  21.920705
# FL       18.726075  20.115906
# HA        4.900585  -6.915205
# MQ       10.552041  10.774733
# OO       12.586207  11.931034
# UA       12.106073   3.558011
# US        3.782418   2.129595
# VX       12.869421   1.764464
# WN       17.711744   9.649120
# YV       18.996330  15.556985

# %%
df.groupby('carrier').mean()[['dep_delay', 'arr_delay']].plot.bar()

# %%
df['route'] = df['origin'] + ' - ' + df['dest']
df.head()
# Out:
#    sched_dep_time  dep_delay  sched_arr_time  arr_delay carrier origin dest  \
# 0             515        2.0             819       11.0      UA    EWR  IAH
# 1             529        4.0             830       20.0      UA    LGA  IAH
# 2             540        2.0             850       33.0      AA    JFK  MIA
# 3             545       -1.0            1022      -18.0      B6    JFK  BQN
# 4             600       -6.0             837      -25.0      DL    LGA  ATL
#
#        route
# 0  EWR - IAH
# 1  LGA - IAH
# 2  JFK - MIA
# 3  JFK - BQN
# 4  LGA - ATL

# %%
df['schedule_flight_time'] = df['sched_arr_time'] - df['sched_dep_time']
df.head()
# Out:
#    sched_dep_time  dep_delay  sched_arr_time  arr_delay carrier origin dest  \
# 0             515        2.0             819       11.0      UA    EWR  IAH
# 1             529        4.0             830       20.0      UA    LGA  IAH
# 2             540        2.0             850       33.0      AA    JFK  MIA
# 3             545       -1.0            1022      -18.0      B6    JFK  BQN
# 4             600       -6.0             837      -25.0      DL    LGA  ATL
#
#        route  schedule_flight_time
# 0  EWR - IAH                   304
# 1  LGA - IAH                   301
# 2  JFK - MIA                   310
# 3  JFK - BQN                   477
# 4  LGA - ATL                   237

# %%
df.groupby(['route', 'carrier']).mean()
# Out:
#                    sched_dep_time  dep_delay  sched_arr_time   arr_delay  \
# route     carrier
# EWR - ALB EV          1609.831435  23.620525     1717.993166   14.397129
# EWR - ANC UA          1617.500000  12.875000     1965.500000   -2.500000
# EWR - ATL 9E           922.500000  -5.750000     1166.500000   -6.250000
#           DL          1231.333968  11.880846     1466.446559    9.996470
#           EV          1335.293417  22.336943     1586.334279   19.546554
# ...                           ...        ...             ...         ...
# LGA - TVC EV          1241.363636  33.000000     1478.818182   16.875000
#           MQ          1603.333333  11.787879     1811.666667   14.878788
# LGA - TYS 9E          1991.753247  12.705660     2219.590909    3.894340
# LGA - XNA EV          1100.000000  71.000000     1245.000000  119.000000
#           MQ          1316.189516   5.843923     1555.416667    6.956215
#
#                    schedule_flight_time
# route     carrier
# EWR - ALB EV                 108.161731
# EWR - ANC UA                 348.000000
# EWR - ATL 9E                 244.000000
#           DL                 235.112591
#           EV                 251.040863
# ...                                 ...
# LGA - TVC EV                 237.454545
#           MQ                 208.333333
# LGA - TYS 9E                 227.837662
# LGA - XNA EV                 145.000000
#           MQ                 239.227151
#
# [439 rows x 5 columns]

# %%
df.groupby(['route', 'carrier']).mean()[:50]

# %%
df.sort_values('dep_delay')
# Out:
#         sched_dep_time  dep_delay  sched_arr_time  arr_delay carrier origin  \
# 89673             2123      -43.0            2352       48.0      B6    JFK
# 113633            2055      -33.0            2338      -58.0      DL    LGA
# 64501             1440      -32.0            1559      -10.0      EV    LGA
# 9619              1930      -30.0            2243      -10.0      DL    LGA
# 24915             1730      -27.0            1957      -10.0      F9    LGA
# ...                ...        ...             ...        ...     ...    ...
# 336771            1455        NaN            1634        NaN      9E    JFK
# 336772            2200        NaN            2312        NaN      9E    LGA
# 336773            1210        NaN            1330        NaN      MQ    LGA
# 336774            1159        NaN            1344        NaN      MQ    LGA
# 336775             840        NaN            1020        NaN      MQ    LGA
#
#        dest      route  schedule_flight_time
# 89673   DEN  JFK - DEN                   229
# 113633  MSY  LGA - MSY                   283
# 64501   IAD  LGA - IAD                   119
# 9619    TPA  LGA - TPA                   313
# 24915   DEN  LGA - DEN                   227
# ...     ...        ...                   ...
# 336771  DCA  JFK - DCA                   179
# 336772  SYR  LGA - SYR                   112
# 336773  BNA  LGA - BNA                   120
# 336774  CLE  LGA - CLE                   185
# 336775  RDU  LGA - RDU                   180
#
# [336776 rows x 9 columns]

# %%
df.dropna(subset=['dep_delay']).sort_values('dep_delay')

# %%
df.dropna(subset=['dep_delay']).sort_values('dep_delay', ascending=False)

# %%
df.dropna(subset=['dep_delay']).sort_values(['carrier', 'dep_delay'])
