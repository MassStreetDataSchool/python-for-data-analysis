# %%
import matplotlib.pyplot as plt
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/home/martin/.local/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
import numpy as np
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
plt.title('Sin from 0 to 2*pi')
plt.plot(x,y)
plt.show()

# %%
plt.title('Sin from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x,y)
plt.show()

# %%
y2 = np.cos(x)
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, y)
plt.plot(x, y2)
plt.show()

# %%
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, y, label='sine')
plt.plot(x, y2, label='cosine')
plt.legend()
plt.show()

# %%
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend()
plt.show()

# %%
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend(loc='lower center')
plt.show()
